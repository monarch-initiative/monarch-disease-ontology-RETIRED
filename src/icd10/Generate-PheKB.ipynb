# %%
from ontobio import OntologyFactory
ofa = OntologyFactory()

# %%
icd = ofa.create("icd10.json")

# %%
hp = ofa.create('hp')

# %%
hpsimple = hp.subontology(relations='subClassOf')

# %%
# Read in the previously generated mappings
import pandas as pd
df=pd.read_csv('ontobio-align-hp.tsv',sep="\t")

# %%
df[0:10]
# Out:
#                                           left  \
# 0   http://purl.obolibrary.org/obo/ICD10_H16.0
# 1  http://purl.obolibrary.org/obo/ICD10_M26.01
# 2   http://purl.obolibrary.org/obo/ICD10_L94.6
# 3   http://purl.obolibrary.org/obo/ICD10_I44.4
# 4  http://purl.obolibrary.org/obo/ICD10_R47.81
# 5   http://purl.obolibrary.org/obo/ICD10_Q17.5
# 6   http://purl.obolibrary.org/obo/ICD10_Q25.3
# 7   http://purl.obolibrary.org/obo/ICD10_Q79.0
# 8   http://purl.obolibrary.org/obo/ICD10_H05.4
# 9     http://purl.obolibrary.org/obo/ICD10_F31
#
#                         left_label       right  \
# 0                    Corneal ulcer  HP:0012804
# 1            Maxillary hyperplasia  HP:0430028
# 2                           Ainhum  HP:0031009
# 3   Left anterior fascicular block  HP:0011711
# 4                   Slurred speech  HP:0001350
# 5                    Prominent ear  HP:0000411
# 6    Supravalvular aortic stenosis  HP:0004381
# 7  Congenital diaphragmatic hernia  HP:0000776
# 8                     Enophthalmos  HP:0000490
# 9                 bipolar disorder  HP:0007302
#
#                        right_label left_match_type right_match_type  \
# 0               Corneal ulceration           label  hasExactSynonym
# 1       Hyperplasia of the maxilla           label  hasExactSynonym
# 2                           Ainhum           label            label
# 3   Left anterior fascicular block           label            label
# 4                   Slurred speech           label            label
# 5                   Protruding ear           label  hasExactSynonym
# 6    Supravalvular aortic stenosis           label            label
# 7  Congenital diaphragmatic hernia           label            label
# 8                   Deeply set eye           label  hasExactSynonym
# 9       Bipolar affective disorder           label  hasExactSynonym
#
#                     left_match_val                  right_match_val  score  \
# 0                    Corneal ulcer                    Corneal ulcer   90.0
# 1            Maxillary hyperplasia            Maxillary hyperplasia   90.0
# 2                           Ainhum                           Ainhum  100.0
# 3   Left anterior fascicular block   Left anterior fascicular block  100.0
# 4                   Slurred speech                   Slurred speech  100.0
# 5                    Prominent ear                    Prominent ear   90.0
# 6    Supravalvular aortic stenosis    Supravalvular aortic stenosis  100.0
# 7  Congenital diaphragmatic hernia  Congenital diaphragmatic hernia  100.0
# 8                     Enophthalmos                     Enophthalmos   90.0
# 9                 bipolar disorder                 Bipolar disorder   90.0
#
#    left_simscore  right_simscore  reciprocal_score  conditional_pr_equiv  \
# 0            0.5             1.0                 4                   1.0
# 1            1.0             1.0                 4                   1.0
# 2            1.0             1.0                 4                   1.0
# 3            1.0             1.0                 4                   1.0
# 4            1.0             1.0                 4                   1.0
# 5            1.0             1.0                 4                   1.0
# 6            1.0             1.0                 4                   1.0
# 7            0.5             1.0                 4                   1.0
# 8            1.0             1.0                 4                   1.0
# 9            0.5             1.0                 4                   1.0
#
#    equiv_clique_size
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# 5                  2
# 6                  2
# 7                  2
# 8                  2
# 9                  2

# %%
svas = df.loc[df['right'] == 'HP:0004381']
svas
# Out:
#                                          left                     left_label  \
# 6  http://purl.obolibrary.org/obo/ICD10_Q25.3  Supravalvular aortic stenosis
#
#         right                    right_label left_match_type right_match_type  \
# 6  HP:0004381  Supravalvular aortic stenosis           label            label
#
#                   left_match_val                right_match_val  score  \
# 6  Supravalvular aortic stenosis  Supravalvular aortic stenosis  100.0
#
#    left_simscore  right_simscore  reciprocal_score  conditional_pr_equiv  \
# 6            1.0             1.0                 4                   1.0
#
#    equiv_clique_size
# 6                  2

# %%
from collections import defaultdict
hp2icd = defaultdict(list)
for _,row in df.iterrows():
    hp2icd[row['right']].append(row['left'])
    
hp2icd['HP:0004381']
# Out:
# ['http://purl.obolibrary.org/obo/ICD10_Q25.3']

# %%
from ontobio import AssociationSetFactory
afa = AssociationSetFactory()

# %%
aset = afa.create(ontology=hp, subject_category='disease', object_category='phenotype', taxon='NCBITaxon:9606')

# %%
def rollup(hpterm):
    mterms = set(hp2icd[hpterm])
    if len(mterms) > 0:
        return mterms
    for p in hpsimple.parents(hpterm):
        #print("P {} ->{}".format(hpterm,p))
        mterms.update(rollup(p))
    return mterms

def test_rollup(t):
    print("ROLLING UP: {} {}".format(t,hp.label(t)))
    terms = rollup(t)
    print(" --> {}".format( ["{} {}".format(x,icd.label(x)) for x in terms] ))
    
# test on one with direct mapping
test_rollup('HP:0004381')

# test on one with no direct mapping
test_rollup('HP:0005173')
# Out:
# ROLLING UP: HP:0004381 Supravalvular aortic stenosis
#  --> ['http://purl.obolibrary.org/obo/ICD10_Q25.3 Supravalvular aortic stenosis']
# ROLLING UP: HP:0005173 Calcific aortic valve stenosis
#  --> []

# %%
d2icd = {}
for d in aset.subjects:
    hpterms = aset.annotations(d)
    mterms = set()
    for t in hpterms:
        mterms.update(rollup(t))
    d2icd[d] = mterms

# %%
def show_phekb(d):
    print("\nTESTING: {} {}".format(d,aset.label(d)))
    print("  HPO PROFILE: {}".format( ["{} {}".format(t,hp.label(t)) for t in aset.annotations(d)] ))
    mterms = d2icd[d]
    print("  ROLLED UP: {}".format( ["{} {}".format(t,icd.label(t)) for t in mterms] ))

show_phekb('OMIM:118450')
show_phekb('OMIM:610205')
# Out:
# TESTING: OMIM:118450 Alagille syndrome 1
#   HPO PROFILE: ['HP:0001394 Cirrhosis', 'HP:0001738 Exocrine pancreatic insufficiency', 'HP:0001328 Specific learning disability', 'HP:0000627 Posterior embryotoxon', 'HP:0003189 Long nose', 'HP:0004969 Peripheral pulmonary artery stenosis', 'HP:0006571 Reduced number of intrahepatic bile ducts', 'HP:0005280 Depressed nasal bridge', 'HP:0001284 Areflexia', 'HP:0002910 Elevated hepatic transaminases', 'HP:0000482 Microcornea', 'HP:0001680 Coarctation of aorta', 'HP:0000400 Macrotia', 'HP:0000585 Band keratopathy', 'HP:0000076 Vesicoureteral reflux', 'HP:0001256 Intellectual disability, mild', 'HP:0000772 Abnormality of the ribs', 'HP:0000533 Chorioretinal atrophy', 'HP:0001492 Axenfeld anomaly', 'HP:0000518 Cataract', 'HP:0006579 Prolonged neonatal jaundice', 'HP:0001297 Stroke', 'HP:0000316 Hypertelorism', 'HP:0000337 Broad forehead', 'HP:0000545 Myopia', 'HP:0001631 Atrial septal defect', 'HP:0000089 Renal hypoplasia', 'HP:0002155 Hypertriglyceridemia', 'HP:0001636 Tetralogy of Fallot', 'HP:0001508 Failure to thrive', 'HP:0000582 Upslanted palpebral fissure', 'HP:0008659 Multiple small medullary renal cysts', 'HP:0000490 Deeply set eye', 'HP:0002937 Hemivertebrae', 'HP:0001947 Renal tubular acidosis', 'HP:0001629 Ventricular septal defect', 'HP:0004617 Butterfly vertebral arch', 'HP:0002895 Papillary thyroid carcinoma', 'HP:0009882 Short distal phalanx of finger', 'HP:0001402 Hepatocellular carcinoma', 'HP:0007702 Pigmentary retinal deposits', 'HP:0003124 Hypercholesterolemia', 'HP:0000325 Triangular face', 'HP:0000110 Renal dysplasia', 'HP:0003022 Hypoplasia of the ulna', 'HP:0000486 Strabismus']
#   ROLLED UP: ['http://purl.obolibrary.org/obo/ICD10_F70.F79 Mental retardation', 'http://purl.obolibrary.org/obo/ICD10_Q75.2 Hypertelorism', 'http://purl.obolibrary.org/obo/ICD10_Q21.0 Ventricular septal defect', 'http://purl.obolibrary.org/obo/ICD10_Q25.6 Stenosis of pulmonary artery', 'http://purl.obolibrary.org/obo/ICD10_Q61 Cystic kidney disease', 'http://purl.obolibrary.org/obo/ICD10_K86.81 Exocrine pancreatic insufficiency', 'http://purl.obolibrary.org/obo/ICD10_Q21.3 Tetralogy of Fallot', 'http://purl.obolibrary.org/obo/ICD10_H05.4 Enophthalmos', 'http://purl.obolibrary.org/obo/ICD10_Q21.1 Atrial septal defect', 'http://purl.obolibrary.org/obo/ICD10_Q17.1 Macrotia', 'http://purl.obolibrary.org/obo/ICD10_E87.2 Acidosis', 'http://purl.obolibrary.org/obo/ICD10_H52.1 Myopia', 'http://purl.obolibrary.org/obo/ICD10_Q25.1 Coarctation of aorta', 'http://purl.obolibrary.org/obo/ICD10_Q61.4 Renal dysplasia']
#
# TESTING: OMIM:610205 Alagille syndrome due to a NOTCH2 point mutation
#   HPO PROFILE: ['HP:0000337 Broad forehead', 'HP:0000083 Renal insufficiency', 'HP:0001631 Atrial septal defect', 'HP:0000325 Triangular face', 'HP:0004969 Peripheral pulmonary artery stenosis', 'HP:0001396 Cholestasis', 'HP:0001947 Renal tubular acidosis']
#   ROLLED UP: ['http://purl.obolibrary.org/obo/ICD10_N17.N19 Renal failure', 'http://purl.obolibrary.org/obo/ICD10_Q21.1 Atrial septal defect', 'http://purl.obolibrary.org/obo/ICD10_E87.2 Acidosis', 'http://purl.obolibrary.org/obo/ICD10_Q25.6 Stenosis of pulmonary artery']
