# %%
# Ontology factories are used to make ontologies from
# either local files or remote services
from ontobio import OntologyFactory
ofa = OntologyFactory()

# %%
# Use the makefile to generate an obojson version of ICD10
icd = ofa.create("icd10.json")

# %%
# Create HP ontology object using default method (remote services)
hp = ofa.create('hp')

# %%
# Make a simple version of HPO with no inter-ontology links
hpsimple = hp.subontology(relations='subClassOf')

# %%
# Read in the previously generated mappings
# (see Makefile for generation)
import pandas as pd
df=pd.read_csv('ontobio-align-hp.tsv',sep="\t")

# %%
# Show sample rows
df[0:10]
# Out:
#                                           left  \
# 0   http://purl.obolibrary.org/obo/ICD10_Q66.4
# 1  http://purl.obolibrary.org/obo/ICD10_Q25.72
# 2   http://purl.obolibrary.org/obo/ICD10_E26.1
# 3   http://purl.obolibrary.org/obo/ICD10_G71.0
# 4   http://purl.obolibrary.org/obo/ICD10_G71.0
# 5  http://purl.obolibrary.org/obo/ICD10_N50.82
# 6   http://purl.obolibrary.org/obo/ICD10_Q54.1
# 7   http://purl.obolibrary.org/obo/ICD10_R63.0
# 8  http://purl.obolibrary.org/obo/ICD10_Q52.11
# 9  http://purl.obolibrary.org/obo/ICD10_H57.02
#
#                                         left_label       right  \
# 0                Congenital talipes calcaneovalgus  HP:0005850
# 1  Congenital pulmonary arteriovenous malformation  HP:0006548
# 2                     Secondary hyperaldosteronism  HP:0011741
# 3                               Muscular dystrophy  HP:0003560
# 4                               Muscular dystrophy  HP:0003741
# 5                                     Scrotal pain  HP:0030155
# 6                              Hypospadias, penile  HP:0003244
# 7                                         Anorexia  HP:0002039
# 8                        Transverse vaginal septum  HP:0000145
# 9                                       Anisocoria  HP:0009916
#
#                             right_label left_match_type right_match_type  \
# 0     Congenital talipes calcaneovalgus           label            label
# 1  Pulmonary arteriovenous malformation           label            label
# 2          Secondary hyperaldosteronism           label            label
# 3                    Muscular dystrophy           label            label
# 4         Congenital muscular dystrophy           label            label
# 5                          Scrotal pain           label            label
# 6                    Penile hypospadias           label            label
# 7                              Anorexia           label            label
# 8             Transverse vaginal septum           label            label
# 9                            Anisocoria           label            label
#
#                                     left_match_val  \
# 0                Congenital talipes calcaneovalgus
# 1  Congenital pulmonary arteriovenous malformation
# 2                     Secondary hyperaldosteronism
# 3                               Muscular dystrophy
# 4                               Muscular dystrophy
# 5                                     Scrotal pain
# 6                              Hypospadias, penile
# 7                                         Anorexia
# 8                        Transverse vaginal septum
# 9                                       Anisocoria
#
#                         right_match_val   score  left_simscore  \
# 0     Congenital talipes calcaneovalgus  100.00            0.5
# 1  Pulmonary arteriovenous malformation   72.25            0.5
# 2          Secondary hyperaldosteronism  100.00            1.0
# 3                    Muscular dystrophy  100.00            1.0
# 4         Congenital muscular dystrophy   72.25            1.0
# 5                          Scrotal pain  100.00            1.0
# 6                    Penile hypospadias   72.25            1.0
# 7                              Anorexia  100.00            1.0
# 8             Transverse vaginal septum  100.00            1.0
# 9                            Anisocoria  100.00            0.5
#
#    right_simscore  reciprocal_score  conditional_pr_equiv  equiv_clique_size
# 0        1.000000                 0              0.580552                  3
# 1        1.000000                 4              1.000000                  2
# 2        1.000000                 4              1.000000                  2
# 3        0.500000                 0              0.580552                  3
# 4        0.500000                 2              0.419448                  3
# 5        0.500000                 4              1.000000                  2
# 6        0.666667                 4              1.000000                  2
# 7        1.000000                 4              1.000000                  2
# 8        1.000000                 4              1.000000                  2
# 9        1.000000                 4              1.000000                  2

# %%
## Query by row
svas = df.loc[df['right'] == 'HP:0004381']
svas
# Out:
#                                            left  \
# 596  http://purl.obolibrary.org/obo/ICD10_Q25.3
#
#                         left_label       right                    right_label  \
# 596  Supravalvular aortic stenosis  HP:0004381  Supravalvular aortic stenosis
#
#     left_match_type right_match_type                 left_match_val  \
# 596           label            label  Supravalvular aortic stenosis
#
#                    right_match_val  score  left_simscore  right_simscore  \
# 596  Supravalvular aortic stenosis  100.0            0.5             1.0
#
#      reciprocal_score  conditional_pr_equiv  equiv_clique_size
# 596                 4                   1.0                  2

# %%
## Make a mapping
from collections import defaultdict
hp2icd = defaultdict(list)
for _,row in df.iterrows():
    hp2icd[row['right']].append(row['left'])
    
# test it
hp2icd['HP:0004381']
# Out:
# ['http://purl.obolibrary.org/obo/ICD10_Q25.3']

# %%
## Use associationset factory to make assocset from
## Remote services (Monarch)
from ontobio import AssociationSetFactory
afa = AssociationSetFactory()

# %%
aset = afa.create(ontology=hp, subject_category='disease', object_category='phenotype', taxon='NCBITaxon:9606')

# %%
## rollup an HP term.
## Algorithm:
##  use direct mapping if available
##  otherwise recursively call on all parents, and take union of results
def rollup(hpterm):
    mterms = set(hp2icd[hpterm])
    if len(mterms) > 0:
        return mterms
    for p in hpsimple.parents(hpterm):
        #print("P {} ->{}".format(hpterm,p))
        mterms.update(rollup(p))
    return mterms

def test_rollup(t):
    print("ROLLING UP: {} {}".format(t,hp.label(t)))
    terms = rollup(t)
    print(" --> {}".format( ["{} {}".format(x,icd.label(x)) for x in terms] ))
    
# test on one with direct mapping
test_rollup('HP:0004381')

# test on one with no direct mapping;
# we expect a mapping for the parent
test_rollup('HP:0005173')
# Out:
# ROLLING UP: HP:0004381 Supravalvular aortic stenosis
#  --> ['http://purl.obolibrary.org/obo/ICD10_Q25.3 Supravalvular aortic stenosis']
# ROLLING UP: HP:0005173 Calcific aortic valve stenosis
#  --> ['http://purl.obolibrary.org/obo/ICD10_Q23.0 Congenital stenosis of aortic valve']

# %%
## Create disease-to-ICD10 mappings
d2icd = {}
for d in aset.subjects:
    hpterms = aset.annotations(d)
    mterms = set()
    for t in hpterms:
        mterms.update(rollup(t))
    d2icd[d] = mterms

# %%
## Test it
def show_phekb(d):
    print("\nTESTING: {} {}".format(d,aset.label(d)))
    print("  HPO PROFILE:")
    for t in aset.annotations(d):
        print("    {} {}".format(t,hp.label(t)))
    print("  ICD ROLLUP PROFILE:")
    mterms = d2icd[d]
    for t in mterms:
        print("    {} {}".format(t,icd.label(t)))

show_phekb('OMIM:118450')
show_phekb('OMIM:610205')
# Out:
# TESTING: OMIM:118450 Alagille syndrome 1
#   HPO PROFILE:
#     HP:0001394 Cirrhosis
#     HP:0001738 Exocrine pancreatic insufficiency
#     HP:0001328 Specific learning disability
#     HP:0000627 Posterior embryotoxon
#     HP:0003189 Long nose
#     HP:0004969 Peripheral pulmonary artery stenosis
#     HP:0006571 Reduced number of intrahepatic bile ducts
#     HP:0005280 Depressed nasal bridge
#     HP:0001284 Areflexia
#     HP:0002910 Elevated hepatic transaminases
#     HP:0000482 Microcornea
#     HP:0001680 Coarctation of aorta
#     HP:0000400 Macrotia
#     HP:0000585 Band keratopathy
#     HP:0000076 Vesicoureteral reflux
#     HP:0001256 Intellectual disability, mild
#     HP:0000772 Abnormality of the ribs
#     HP:0000533 Chorioretinal atrophy
#     HP:0001492 Axenfeld anomaly
#     HP:0000518 Cataract
#     HP:0006579 Prolonged neonatal jaundice
#     HP:0001297 Stroke
#     HP:0000316 Hypertelorism
#     HP:0000337 Broad forehead
#     HP:0000545 Myopia
#     HP:0001631 Atrial septal defect
#     HP:0000089 Renal hypoplasia
#     HP:0002155 Hypertriglyceridemia
#     HP:0001636 Tetralogy of Fallot
#     HP:0001508 Failure to thrive
#     HP:0000582 Upslanted palpebral fissure
#     HP:0008659 Multiple small medullary renal cysts
#     HP:0000490 Deeply set eye
#     HP:0002937 Hemivertebrae
#     HP:0001947 Renal tubular acidosis
#     HP:0001629 Ventricular septal defect
#     HP:0004617 Butterfly vertebral arch
#     HP:0002895 Papillary thyroid carcinoma
#     HP:0009882 Short distal phalanx of finger
#     HP:0001402 Hepatocellular carcinoma
#     HP:0007702 Pigmentary retinal deposits
#     HP:0003124 Hypercholesterolemia
#     HP:0000325 Triangular face
#     HP:0000110 Renal dysplasia
#     HP:0003022 Hypoplasia of the ulna
#     HP:0000486 Strabismus
#   ICD ROLLUP PROFILE:
#     http://purl.obolibrary.org/obo/ICD10_Q13.3 Congenital corneal opacity
#     http://purl.obolibrary.org/obo/ICD10_Q60.Q64 Congenital malformations of the urinary system
#     http://purl.obolibrary.org/obo/ICD10_K86.81 Exocrine pancreatic insufficiency
#     http://purl.obolibrary.org/obo/ICD10_Q30 Congenital malformations of nose
#     http://purl.obolibrary.org/obo/ICD10_Q17.1 Macrotia
#     http://purl.obolibrary.org/obo/ICD10_H52.1 Myopia
#     http://purl.obolibrary.org/obo/ICD10_Q61.4 Renal dysplasia
#     http://purl.obolibrary.org/obo/ICD10_Q25.1 Coarctation of aorta
#     http://purl.obolibrary.org/obo/ICD10_Q13 Congenital malformations of anterior segment of eye
#     http://purl.obolibrary.org/obo/ICD10_F70.F79 Mental retardation
#     http://purl.obolibrary.org/obo/ICD10_Q75.2 Hypertelorism
#     http://purl.obolibrary.org/obo/ICD10_Q21.0 Ventricular septal defect
#     http://purl.obolibrary.org/obo/ICD10_Q12.0 Congenital cataract
#     http://purl.obolibrary.org/obo/ICD10_P78.81 Congenital cirrhosis (of liver)
#     http://purl.obolibrary.org/obo/ICD10_Q25.6 Stenosis of pulmonary artery
#     http://purl.obolibrary.org/obo/ICD10_Q61 Cystic kidney disease
#     http://purl.obolibrary.org/obo/ICD10_Q00.Q07 Congenital malformations of the nervous system
#     http://purl.obolibrary.org/obo/ICD10_Q21.3 Tetralogy of Fallot
#     http://purl.obolibrary.org/obo/ICD10_Q21.1 Atrial septal defect
#     http://purl.obolibrary.org/obo/ICD10_E87.2 Acidosis
#     http://purl.obolibrary.org/obo/ICD10_H05.4 Enophthalmos
#
# TESTING: OMIM:610205 Alagille syndrome due to a NOTCH2 point mutation
#   HPO PROFILE:
#     HP:0000337 Broad forehead
#     HP:0000083 Renal insufficiency
#     HP:0001631 Atrial septal defect
#     HP:0000325 Triangular face
#     HP:0004969 Peripheral pulmonary artery stenosis
#     HP:0001396 Cholestasis
#     HP:0001947 Renal tubular acidosis
#   ICD ROLLUP PROFILE:
#     http://purl.obolibrary.org/obo/ICD10_N17.N19 Renal failure
#     http://purl.obolibrary.org/obo/ICD10_Q21.1 Atrial septal defect
#     http://purl.obolibrary.org/obo/ICD10_Q60.Q64 Congenital malformations of the urinary system
#     http://purl.obolibrary.org/obo/ICD10_E87.2 Acidosis
#     http://purl.obolibrary.org/obo/ICD10_Q25.6 Stenosis of pulmonary artery
#     http://purl.obolibrary.org/obo/ICD10_P96.0 Congenital renal failure
